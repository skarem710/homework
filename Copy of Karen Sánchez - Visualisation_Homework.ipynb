# %%
# !!!!!Import rest of the libraries required
import seaborn as sns
import matplotlib.pyplot as plt


# Load the Diamonds dataset from Seaborn
diamonds_data = sns.load_dataset("diamonds")
diamonds_data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
## STATISTICS challenge:

# calculate the mean of the price by cut
# calculate the standard deviation of the price by cut
# calculate the median of the price by cut
# calculate the mode of the price by cut
# calculate the variance of the price by cut
# calculate the 25 and 75 percentile of the price by cut
# calculate the range of the price by cut

# bonus 1:
# is there a correlation between the price and the carat? If so, what kind of correlation is it?
# what about covariance?


# bonus 2 if you have a lot of time:
# make a function on your own that calculates the standard deviation of a list of numbers (you can find the formula in last weeks slides)

# %%
# calculate the mean of the price by cut
mean_price_by_cut = diamonds_data.groupby('cut')['price'].mean()
mean_price_by_cut
# Out:
# cut
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Good         3928.864452
# Fair         4358.757764
# Name: price, dtype: float64

# %%
# calculate the standard deviation of the price by cut
std_price_by_cut = diamonds_data.groupby('cut')['price'].std()
std_price_by_cut
# Out:
# cut
# Ideal        3808.401172
# Premium      4349.204961
# Very Good    3935.862161
# Good         3681.589584
# Fair         3560.386612
# Name: price, dtype: float64

# %%
# calculate the median of the price by cut
median_price_by_cut = diamonds_data.groupby('cut')['price'].median()
median_price_by_cut
# Out:
# cut
# Ideal        1810.0
# Premium      3185.0
# Very Good    2648.0
# Good         3050.5
# Fair         3282.0
# Name: price, dtype: float64

# %%
# calculate the variance of the price by cut
var_price_by_cut = diamonds_data.groupby('cut')['price'].var()
print(var_price_by_cut)
# Out:
# cut
# Ideal        1.450392e+07
# Premium      1.891558e+07
# Very Good    1.549101e+07
# Good         1.355410e+07
# Fair         1.267635e+07
# Name: price, dtype: float64

# %%
# calculate the 25 and 75 percentile of the price by cut
qtl_price_by_cut = diamonds_data.groupby('cut')['price'].quantile([0.25, 0.75] )
qtl_price_by_cut
# Out:
# cut
# Ideal      0.25     878.00
#            0.75    4678.50
# Premium    0.25    1046.00
#            0.75    6296.00
# Very Good  0.25     912.00
#            0.75    5372.75
# Good       0.25    1145.00
#            0.75    5028.00
# Fair       0.25    2050.25
#            0.75    5205.50
# Name: price, dtype: float64

# %%
import pandas as pd

# %%
# calculate the range of the price by cut
range_price_by_cut = (diamonds_data.groupby('cut')['price']).agg(['min','max'])
range_price_by_cut
# Out:
#            min    max
# cut
# Ideal      326  18806
# Premium    326  18823
# Very Good  336  18818
# Good       327  18788
# Fair       337  18574

# %%
# is there a correlation between the price and the carat?
corr_price_carat = diamonds_data['price'].corr(diamonds_data['carat'])
corr_price_carat
# Out:
# 0.921591301193477

# %%
# 1. Boxplot of Diamond Price Vs Cut
plt.figure(figsize=(10, 5))
sb.boxplot( x='cut', y= 'price', data = diamonds_data)
plt.xlabel ('Cut')
plt.ylabel('price')
plt.title('Diamond Price Vs Cut')
plt.show()

# %%
# 2. Barplot: Average Diamond Price by Color
price_by_color = diamonds_data.groupby('color')['price'].mean()
plt.figure(figsize=(8,6))
plt.bar(price_by_color.index, price_by_color.values, color='violet')
plt.xlabel('Color')
plt.ylabel('Price')
plt.title('Average Dimond Price By Color')
plt.show()

# %%
# 3. Scatterplot with Facets: Scatterplot of Carat vs. Price by Cut"

# %%
# 4. Pie Chart: Distribution of Diamond Cut

# %%
# Create a correlation matrix
correlation_matrix = diamonds_data.corr()

# Create a correlation plot
